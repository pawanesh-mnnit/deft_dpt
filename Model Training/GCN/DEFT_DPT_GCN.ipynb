# %% [markdown]
# ### Import Labraries

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Features

# %%
features_df = pd.read_csv("../Feature_WM_Level/Feature_S2_Cheese_C1_GTEA.csv")
action_classes = sorted(features_df["Action_class"].unique())
action_mapping = {action_classes[i]: i for i in range(len(action_classes))}
features_df["action_class_mapped"] = features_df["Action_class"].map(action_mapping)
train_df, test_df = train_test_split(features_df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)
def process_data(df):
    X = torch.tensor(df.iloc[:, 3:].values, dtype=torch.float32)
    y = torch.tensor(df["action_class_mapped"].values, dtype=torch.long)
    return X, y

X_train, y_train = process_data(train_df)
X_val, y_val = process_data(val_df)
X_test, y_test = process_data(test_df)

# %% [markdown]
# ### SVSG Graph using Dynamic Percentile Threhold +

# %%
def dynamic_percentile_graph(X, percentile=98, device='cuda'):
    X = X.to(device)
    N = X.shape[0]
    sim_matrix = F.cosine_similarity(X.unsqueeze(1), X.unsqueeze(0), dim=2)
    threshold = torch.quantile(sim_matrix, percentile / 100)
    adj_matrix = (sim_matrix >= threshold).float()
    adj_matrix.fill_diagonal_(0)
    row_indices, col_indices = torch.nonzero(adj_matrix, as_tuple=True)
    edge_index = torch.stack([row_indices, col_indices], dim=0)
    return edge_index

# GCN Model
class GCNModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# Multi-Task Loss
class MultiTaskLoss(nn.Module):
    def __init__(self, alpha=0.8):
        super(MultiTaskLoss, self).__init__()
        self.ce_loss = nn.CrossEntropyLoss()
        self.alpha = alpha

    def forward(self, outputs, targets, features):
        ce = self.ce_loss(outputs, targets)
        temporal_loss = torch.mean(torch.abs(features[1:] - features[:-1]))
        return self.alpha * ce + (1 - self.alpha) * temporal_loss

# %%
# Model Initialization
input_dim = X_train.shape[1]
hidden_dim = 128
output_dim = features_df['action_class_mapped'].nunique()
model = GCNModel(input_dim, hidden_dim, output_dim)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Optimizer and Loss
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = MultiTaskLoss()

# %%
# Training Loop
from sklearn.metrics import precision_score, recall_score, f1_score
num_epochs = 100
percentile_threshold = 98

for epoch in range(num_epochs):
    model.train()
    edge_index = dynamic_percentile_graph(X_train, percentile=percentile_threshold).to(device)
    optimizer.zero_grad()
    output = model(X_train.to(device), edge_index)
    loss = criterion(output, y_train.to(device), X_train.to(device))
    loss.backward()
    optimizer.step()

    # Validation
    model.eval()
    with torch.no_grad():
        edge_index_val = dynamic_percentile_graph(X_val, percentile=percentile_threshold).to(device)
        val_output = model(X_val.to(device), edge_index_val)
        val_loss = criterion(val_output, y_val.to(device), X_val.to(device))
        val_probs = torch.softmax(val_output, dim=1)
        val_preds = val_probs.argmax(dim=1).cpu().numpy()

        top1_correct = (val_preds == y_val.cpu().numpy()).sum()
        top1_acc = top1_correct / len(y_val)

        precision = precision_score(y_val.cpu().numpy(), val_preds, average='weighted', zero_division=1)
        recall = recall_score(y_val.cpu().numpy(), val_preds, average='weighted', zero_division=1)
        f1 = f1_score(y_val.cpu().numpy(), val_preds, average='weighted', zero_division=1)

        top5_preds = torch.topk(val_probs, 5, dim=1).indices.cpu().numpy()
        top5_correct = sum([y in top5 for y, top5 in zip(y_val.cpu().numpy(), top5_preds)])
        top5_acc = top5_correct / len(y_val)

        print(f"Epoch {epoch+1}/{num_epochs} - "
              f"Loss: {loss.item():.4f} - "
              f"Val Loss: {val_loss.item():.4f} - "
              f"Top-1 Acc: {top1_acc:.4f} - "
              f"Top-5 Acc: {top5_acc:.4f} - "
              f"Precision: {precision:.4f} - "
              f"Recall: {recall:.4f} - "
              f"F1-Score: {f1:.4f}")
# Out:
# Epoch 1/100 - Loss: 2.7824 - Val Loss: 2.4227 - Top-1 Acc: 0.0196 - Top-5 Acc: 0.2745 - Precision: 0.9711 - Recall: 0.0196 - F1-Score: 0.0009
# Epoch 2/100 - Loss: 2.4096 - Val Loss: 2.0888 - Top-1 Acc: 0.0294 - Top-5 Acc: 0.4608 - Precision: 0.8975 - Recall: 0.0294 - F1-Score: 0.0182
# Epoch 3/100 - Loss: 2.0647 - Val Loss: 1.7941 - Top-1 Acc: 0.0686 - Top-5 Acc: 0.7549 - Precision: 0.4774 - Recall: 0.0686 - F1-Score: 0.0835
# Epoch 4/100 - Loss: 1.7606 - Val Loss: 1.5511 - Top-1 Acc: 0.3824 - Top-5 Acc: 0.8824 - Precision: 0.5747 - Recall: 0.3824 - F1-Score: 0.3561
# Epoch 5/100 - Loss: 1.5092 - Val Loss: 1.3735 - Top-1 Acc: 0.5196 - Top-5 Acc: 0.8431 - Precision: 0.7232 - Recall: 0.5196 - F1-Score: 0.4034
# Epoch 6/100 - Loss: 1.3235 - Val Loss: 1.2675 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8431 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 7/100 - Loss: 1.2082 - Val Loss: 1.2205 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8529 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 8/100 - Loss: 1.1542 - Val Loss: 1.2086 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8627 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 9/100 - Loss: 1.1373 - Val Loss: 1.2095 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8824 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 10/100 - Loss: 1.1334 - Val Loss: 1.2093 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8824 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 11/100 - Loss: 1.1291 - Val Loss: 1.2031 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.8725 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 12/100 - Loss: 1.1188 - Val Loss: 1.1901 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.9020 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 13/100 - Loss: 1.1027 - Val Loss: 1.1736 - Top-1 Acc: 0.5882 - Top-5 Acc: 0.9412 - Precision: 0.7578 - Recall: 0.5882 - F1-Score: 0.4357
# Epoch 14/100 - Loss: 1.0842 - Val Loss: 1.1574 - Top-1 Acc: 0.5980 - Top-5 Acc: 0.9118 - Precision: 0.7612 - Recall: 0.5980 - F1-Score: 0.4568
# Epoch 15/100 - Loss: 1.0666 - Val Loss: 1.1438 - Top-1 Acc: 0.6078 - Top-5 Acc: 0.9118 - Precision: 0.6874 - Recall: 0.6078 - F1-Score: 0.4790
# Epoch 16/100 - Loss: 1.0518 - Val Loss: 1.1331 - Top-1 Acc: 0.6176 - Top-5 Acc: 0.9118 - Precision: 0.6953 - Recall: 0.6176 - F1-Score: 0.4967
# Epoch 17/100 - Loss: 1.0406 - Val Loss: 1.1234 - Top-1 Acc: 0.6569 - Top-5 Acc: 0.9118 - Precision: 0.7441 - Recall: 0.6569 - F1-Score: 0.5528
# Epoch 18/100 - Loss: 1.0308 - Val Loss: 1.1118 - Top-1 Acc: 0.6471 - Top-5 Acc: 0.9118 - Precision: 0.7370 - Recall: 0.6471 - F1-Score: 0.5452
# Epoch 19/100 - Loss: 1.0201 - Val Loss: 1.0967 - Top-1 Acc: 0.6569 - Top-5 Acc: 0.9314 - Precision: 0.7493 - Recall: 0.6569 - F1-Score: 0.5576
# Epoch 20/100 - Loss: 1.0071 - Val Loss: 1.0783 - Top-1 Acc: 0.6569 - Top-5 Acc: 0.9314 - Precision: 0.7493 - Recall: 0.6569 - F1-Score: 0.5576
# Epoch 21/100 - Loss: 0.9913 - Val Loss: 1.0577 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9314 - Precision: 0.7554 - Recall: 0.6667 - F1-Score: 0.5653
# Epoch 22/100 - Loss: 0.9736 - Val Loss: 1.0369 - Top-1 Acc: 0.6765 - Top-5 Acc: 0.9314 - Precision: 0.7618 - Recall: 0.6765 - F1-Score: 0.5731
# Epoch 23/100 - Loss: 0.9557 - Val Loss: 1.0173 - Top-1 Acc: 0.6961 - Top-5 Acc: 0.9314 - Precision: 0.7759 - Recall: 0.6961 - F1-Score: 0.5890
# Epoch 24/100 - Loss: 0.9386 - Val Loss: 0.9995 - Top-1 Acc: 0.6765 - Top-5 Acc: 0.9314 - Precision: 0.7602 - Recall: 0.6765 - F1-Score: 0.5703
# Epoch 25/100 - Loss: 0.9233 - Val Loss: 0.9839 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9314 - Precision: 0.7519 - Recall: 0.6667 - F1-Score: 0.5604
# Epoch 26/100 - Loss: 0.9100 - Val Loss: 0.9701 - Top-1 Acc: 0.6765 - Top-5 Acc: 0.9412 - Precision: 0.7603 - Recall: 0.6765 - F1-Score: 0.5682
# Epoch 27/100 - Loss: 0.8982 - Val Loss: 0.9572 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9412 - Precision: 0.7518 - Recall: 0.6667 - F1-Score: 0.5578
# Epoch 28/100 - Loss: 0.8871 - Val Loss: 0.9449 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9412 - Precision: 0.7518 - Recall: 0.6667 - F1-Score: 0.5578
# Epoch 29/100 - Loss: 0.8761 - Val Loss: 0.9326 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9412 - Precision: 0.7518 - Recall: 0.6667 - F1-Score: 0.5578
# Epoch 30/100 - Loss: 0.8647 - Val Loss: 0.9204 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9412 - Precision: 0.7518 - Recall: 0.6667 - F1-Score: 0.5578
# Epoch 31/100 - Loss: 0.8530 - Val Loss: 0.9084 - Top-1 Acc: 0.6667 - Top-5 Acc: 0.9412 - Precision: 0.7518 - Recall: 0.6667 - F1-Score: 0.5578
# Epoch 32/100 - Loss: 0.8409 - Val Loss: 0.8968 - Top-1 Acc: 0.6765 - Top-5 Acc: 0.9412 - Precision: 0.7603 - Recall: 0.6765 - F1-Score: 0.5682
# Epoch 33/100 - Loss: 0.8289 - Val Loss: 0.8857 - Top-1 Acc: 0.6765 - Top-5 Acc: 0.9412 - Precision: 0.7602 - Recall: 0.6765 - F1-Score: 0.5703
# Epoch 34/100 - Loss: 0.8173 - Val Loss: 0.8752 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9412 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 35/100 - Loss: 0.8061 - Val Loss: 0.8655 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9412 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 36/100 - Loss: 0.7953 - Val Loss: 0.8565 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9510 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 37/100 - Loss: 0.7850 - Val Loss: 0.8485 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9510 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 38/100 - Loss: 0.7752 - Val Loss: 0.8412 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9608 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 39/100 - Loss: 0.7657 - Val Loss: 0.8344 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9608 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 40/100 - Loss: 0.7565 - Val Loss: 0.8276 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9608 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 41/100 - Loss: 0.7475 - Val Loss: 0.8208 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9608 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 42/100 - Loss: 0.7385 - Val Loss: 0.8138 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 43/100 - Loss: 0.7295 - Val Loss: 0.8063 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 44/100 - Loss: 0.7204 - Val Loss: 0.7985 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 45/100 - Loss: 0.7111 - Val Loss: 0.7903 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 46/100 - Loss: 0.7018 - Val Loss: 0.7820 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 47/100 - Loss: 0.6928 - Val Loss: 0.7736 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 48/100 - Loss: 0.6842 - Val Loss: 0.7652 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 49/100 - Loss: 0.6761 - Val Loss: 0.7566 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 50/100 - Loss: 0.6681 - Val Loss: 0.7480 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 51/100 - Loss: 0.6603 - Val Loss: 0.7395 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 52/100 - Loss: 0.6527 - Val Loss: 0.7311 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 53/100 - Loss: 0.6452 - Val Loss: 0.7230 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 54/100 - Loss: 0.6378 - Val Loss: 0.7152 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 55/100 - Loss: 0.6304 - Val Loss: 0.7079 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 56/100 - Loss: 0.6231 - Val Loss: 0.7010 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 57/100 - Loss: 0.6158 - Val Loss: 0.6943 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 58/100 - Loss: 0.6086 - Val Loss: 0.6880 - Top-1 Acc: 0.7059 - Top-5 Acc: 0.9706 - Precision: 0.7835 - Recall: 0.7059 - F1-Score: 0.5979
# Epoch 59/100 - Loss: 0.6016 - Val Loss: 0.6820 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9706 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 60/100 - Loss: 0.5948 - Val Loss: 0.6762 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9706 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 61/100 - Loss: 0.5883 - Val Loss: 0.6705 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9706 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 62/100 - Loss: 0.5819 - Val Loss: 0.6648 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9706 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 63/100 - Loss: 0.5756 - Val Loss: 0.6592 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9608 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 64/100 - Loss: 0.5695 - Val Loss: 0.6535 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9608 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 65/100 - Loss: 0.5633 - Val Loss: 0.6479 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9608 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 66/100 - Loss: 0.5573 - Val Loss: 0.6423 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9608 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 67/100 - Loss: 0.5513 - Val Loss: 0.6368 - Top-1 Acc: 0.7255 - Top-5 Acc: 0.9608 - Precision: 0.7938 - Recall: 0.7255 - F1-Score: 0.6309
# Epoch 68/100 - Loss: 0.5454 - Val Loss: 0.6314 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9608 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 69/100 - Loss: 0.5397 - Val Loss: 0.6260 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9706 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 70/100 - Loss: 0.5340 - Val Loss: 0.6208 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9706 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 71/100 - Loss: 0.5285 - Val Loss: 0.6156 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9706 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 72/100 - Loss: 0.5231 - Val Loss: 0.6106 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9804 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 73/100 - Loss: 0.5178 - Val Loss: 0.6057 - Top-1 Acc: 0.7353 - Top-5 Acc: 0.9804 - Precision: 0.7994 - Recall: 0.7353 - F1-Score: 0.6514
# Epoch 74/100 - Loss: 0.5125 - Val Loss: 0.6009 - Top-1 Acc: 0.7451 - Top-5 Acc: 0.9804 - Precision: 0.8056 - Recall: 0.7451 - F1-Score: 0.6684
# Epoch 75/100 - Loss: 0.5073 - Val Loss: 0.5963 - Top-1 Acc: 0.7451 - Top-5 Acc: 0.9804 - Precision: 0.8056 - Recall: 0.7451 - F1-Score: 0.6684
# Epoch 76/100 - Loss: 0.5022 - Val Loss: 0.5918 - Top-1 Acc: 0.7451 - Top-5 Acc: 0.9804 - Precision: 0.8056 - Recall: 0.7451 - F1-Score: 0.6684
# Epoch 77/100 - Loss: 0.4972 - Val Loss: 0.5874 - Top-1 Acc: 0.7451 - Top-5 Acc: 0.9804 - Precision: 0.8056 - Recall: 0.7451 - F1-Score: 0.6684
# Epoch 78/100 - Loss: 0.4922 - Val Loss: 0.5831 - Top-1 Acc: 0.7549 - Top-5 Acc: 0.9804 - Precision: 0.8129 - Recall: 0.7549 - F1-Score: 0.6772
# Epoch 79/100 - Loss: 0.4873 - Val Loss: 0.5790 - Top-1 Acc: 0.7549 - Top-5 Acc: 0.9804 - Precision: 0.8129 - Recall: 0.7549 - F1-Score: 0.6772
# Epoch 80/100 - Loss: 0.4825 - Val Loss: 0.5749 - Top-1 Acc: 0.7647 - Top-5 Acc: 0.9804 - Precision: 0.8184 - Recall: 0.7647 - F1-Score: 0.6965
# Epoch 81/100 - Loss: 0.4778 - Val Loss: 0.5708 - Top-1 Acc: 0.7647 - Top-5 Acc: 0.9804 - Precision: 0.8184 - Recall: 0.7647 - F1-Score: 0.6965
# Epoch 82/100 - Loss: 0.4732 - Val Loss: 0.5668 - Top-1 Acc: 0.7843 - Top-5 Acc: 0.9804 - Precision: 0.8298 - Recall: 0.7843 - F1-Score: 0.7217
# Epoch 83/100 - Loss: 0.4686 - Val Loss: 0.5628 - Top-1 Acc: 0.7843 - Top-5 Acc: 0.9804 - Precision: 0.8298 - Recall: 0.7843 - F1-Score: 0.7217
# Epoch 84/100 - Loss: 0.4641 - Val Loss: 0.5589 - Top-1 Acc: 0.7843 - Top-5 Acc: 0.9804 - Precision: 0.8298 - Recall: 0.7843 - F1-Score: 0.7217
# Epoch 85/100 - Loss: 0.4597 - Val Loss: 0.5549 - Top-1 Acc: 0.7843 - Top-5 Acc: 0.9804 - Precision: 0.8298 - Recall: 0.7843 - F1-Score: 0.7217
# Epoch 86/100 - Loss: 0.4553 - Val Loss: 0.5511 - Top-1 Acc: 0.8039 - Top-5 Acc: 0.9804 - Precision: 0.8418 - Recall: 0.8039 - F1-Score: 0.7586
# Epoch 87/100 - Loss: 0.4511 - Val Loss: 0.5473 - Top-1 Acc: 0.8039 - Top-5 Acc: 0.9804 - Precision: 0.8418 - Recall: 0.8039 - F1-Score: 0.7586
# Epoch 88/100 - Loss: 0.4468 - Val Loss: 0.5436 - Top-1 Acc: 0.8137 - Top-5 Acc: 0.9804 - Precision: 0.8481 - Recall: 0.8137 - F1-Score: 0.7722
# Epoch 89/100 - Loss: 0.4427 - Val Loss: 0.5400 - Top-1 Acc: 0.8137 - Top-5 Acc: 0.9804 - Precision: 0.8481 - Recall: 0.8137 - F1-Score: 0.7722
# Epoch 90/100 - Loss: 0.4386 - Val Loss: 0.5365 - Top-1 Acc: 0.8235 - Top-5 Acc: 0.9804 - Precision: 0.8545 - Recall: 0.8235 - F1-Score: 0.7892
# Epoch 91/100 - Loss: 0.4345 - Val Loss: 0.5332 - Top-1 Acc: 0.8235 - Top-5 Acc: 0.9804 - Precision: 0.8545 - Recall: 0.8235 - F1-Score: 0.7892
# Epoch 92/100 - Loss: 0.4306 - Val Loss: 0.5297 - Top-1 Acc: 0.8235 - Top-5 Acc: 0.9804 - Precision: 0.8545 - Recall: 0.8235 - F1-Score: 0.7892
# Epoch 93/100 - Loss: 0.4266 - Val Loss: 0.5261 - Top-1 Acc: 0.8333 - Top-5 Acc: 0.9804 - Precision: 0.8611 - Recall: 0.8333 - F1-Score: 0.8010
# Epoch 94/100 - Loss: 0.4226 - Val Loss: 0.5227 - Top-1 Acc: 0.8431 - Top-5 Acc: 0.9804 - Precision: 0.8683 - Recall: 0.8431 - F1-Score: 0.8117
# Epoch 95/100 - Loss: 0.4188 - Val Loss: 0.5193 - Top-1 Acc: 0.8431 - Top-5 Acc: 0.9804 - Precision: 0.8683 - Recall: 0.8431 - F1-Score: 0.8117
# Epoch 96/100 - Loss: 0.4151 - Val Loss: 0.5161 - Top-1 Acc: 0.8431 - Top-5 Acc: 0.9804 - Precision: 0.8683 - Recall: 0.8431 - F1-Score: 0.8117
# Epoch 97/100 - Loss: 0.4113 - Val Loss: 0.5130 - Top-1 Acc: 0.8529 - Top-5 Acc: 0.9804 - Precision: 0.8755 - Recall: 0.8529 - F1-Score: 0.8223
# Epoch 98/100 - Loss: 0.4076 - Val Loss: 0.5099 - Top-1 Acc: 0.8529 - Top-5 Acc: 0.9804 - Precision: 0.8755 - Recall: 0.8529 - F1-Score: 0.8223
# Epoch 99/100 - Loss: 0.4040 - Val Loss: 0.5069 - Top-1 Acc: 0.8529 - Top-5 Acc: 0.9804 - Precision: 0.8755 - Recall: 0.8529 - F1-Score: 0.8223
# Epoch 100/100 - Loss: 0.4004 - Val Loss: 0.5039 - Top-1 Acc: 0.8529 - Top-5 Acc: 0.9804 - Precision: 0.8755 - Recall: 0.8529 - F1-Score: 0.8223

# %%
# Final Confusion Matrix
if epoch == num_epochs - 1:
    conf_matrix = confusion_matrix(y_val.cpu().numpy(), val_preds)
    plt.figure(figsize=(10, 5))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix - Validation Set')
    plt.show()

# %%
# Save the model
saved_model_path = "../SavedModels/best_model_gtea.pth"
torch.save(model.state_dict(), saved_model_path)
print(f"Model saved at: {saved_model_path}")

action_label = ['take plate', 'open bin', 'throw leftover', 'close bin', 'put-down plate', 'take sponge', 'squeeze sponge', 'open tap', 
                'rinse sponge', 'take-up liquid', 'pour-up liquid', 'take fork', 'wash fork', 'take knife', 'wash knife', 'put-down knife', 'wash plate','take spatula','rinse spatula','put-down spatula','take colander']
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds',
            xticklabels=action_label, yticklabels=action_label)
